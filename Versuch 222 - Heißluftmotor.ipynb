# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

nt = np.array([6.13,6.93,7.02,7.80])
dnt = np.array([0.17,0.29,0.33,0.30])
nf = np.array([3.15,2.98,2.31,1.24])
dnf = np.array([0.22,0.17,0.26,0.17])
f = np.array([2.83,3.43,3.73,4.57])
df = np.array([0.03,0.02,0.02,0.01])

plt.errorbar(f,nt,xerr=df,yerr=dnt, fmt=".", elinewidth=1, capsize=2, label="$\eta_{th}$", color="red")
plt.errorbar(f,nf,xerr=df,yerr=dnf, fmt=".", elinewidth=1, capsize=2, label="$\eta_{eff}$", color="orange")

plt.xlabel("Drehfrequenz f [1/s]")
plt.ylabel("Wirkungsgrad $\eta$ [%]")
plt.title("Abb.A.1: Thermischer und effektiver Wirkungsgrad,\nabhängig von der Frequenz")
plt.legend()

plt.savefig("C:/Users/Max/v222.pdf", format="pdf")
