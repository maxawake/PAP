# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from numpy import pi as pi

f  = np.array([100,300,600,1000,3000,6000,10000,30000,60000,100000,200000,300000])
u1  = np.array([6.96,6.96,6.98,6.60,4.84,3.10,1.98,0.68,0.35,0.21,0.11,0.07])
u2 = np.array([2.70,2.74,2.74,2.70,2.53,2.12,1.63,0.66,0.34,0.21,0.10,0.07])
u3 = np.array([9.20,9.24,9.24,9.20,8.56,7.12,5.40,2.16,1.12,0.68,0.34,0.23])
u4 = np.array([1.62,1.64,1.63,1.62,1.46,1.14,0.83,0.32,0.16,0.10,0.05,0.04])
x = np.linspace(0,10000,1000)
f2  = np.array([300,600,1000,3000,6000,10000,20000])
u5 = np.array([0.46,0.82,1.12,1.54,1.59,1.58,1.45])

plt.xscale("log")
plt.yscale("log")

plt.plot(f,u1, "--", color="lightgrey")
plt.plot(f,u1, "." , label="$R_G = 680\Omega, U_G = 0.3V_s$")

plt.plot(f,u2, "--", color="lightgrey")
plt.plot(f,u2, ".", label="$R_G = 274k\Omega, U_G = 0.3V_s$")

plt.plot(f,u3, "--", color="lightgrey")
plt.plot(f,u3, ".", label="$R_G = 48.75\Omega, U_G = 1V_s$")

plt.plot(f,u4, "--", color="lightgrey")
plt.plot(f,u4, ".", label="$R_G = 48.75\Omega, C = 560pF$")

plt.plot(f2,u5, "--", color="lightgrey")
plt.plot(f2,u5, ".", label="$R_G = 680\Omega, C = 47nF (EIngang)$")

plt.legend(title="Messdaten für:")
plt.xlabel('Frequenz [Hz]')
plt.ylabel("Verstärakungsfaktor V'")
plt.title('Abbildung #: Frequenzgänge bei verschiedenen Gegenkopplungen')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Abbildung #: Frequenzgänge bei verschiedenen Gegenkopplungen')
